# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
h = np.arange(150, 220, 0.5)
w = ((0.2 * ((h/10) ** 4) + 2 * h + (20000 * np.random.rand(len(h)))) / 4 - 45) / 7000.0

x = np.array([h,w]).T
print(x.shape)
# Out:
# (140, 2)

# %%
axes = plt.gca()
#axes.set_xlim([-40,220])
axes.set_ylim([-3,3])
plt.plot(x[:,0], x[:,1], 'bo')
plt.show()

# %%
print("mean: " + str(np.mean(x, axis=0)))
print("std: " + str(np.std(x, axis=0)))
x -= np.mean(x, axis=0)

axes = plt.gca()
#axes.set_ylim([-10000,10000])
axes.set_ylim([-3,3])
plt.plot(x[:,0], x[:,1], 'go')
plt.show()
# Out:
# mean: [184.75         1.24768911]
# std: [20.20674392  0.45009424]

# %%
print(x.shape)
print("mean: " + str(np.mean(x, axis=0)))
print("std: " + str(np.std(x, axis=0)))
print(np.std(x, axis=0))
x /= (2 * np.std(x, axis=0))
print("mean: " + str(np.mean(x, axis=0)))
print("std: " + str(np.std(x, axis=0)))
axes = plt.gca()
axes.set_ylim([-3,3])
axes.set_xlim([-3,3])
plt.plot(x[:,0], x[:,1], 'ro')
plt.show()
# Out:
# (140, 2)
# mean: [0.00000000e+00 7.61295788e-17]
# std: [20.20674392  0.45009424]
# [20.20674392  0.45009424]
# mean: [0.00000000e+00 5.07530526e-17]
# std: [0.5 0.5]
